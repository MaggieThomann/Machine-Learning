# %% [markdown]
# # Assignment 3:  Decision Tree Implementation
# *Margaret Thomann - February 17, 2018 *
#
# In this assignment, I will construct a decision tree from the data provided about heart disease.

# %% [markdown]
# ### Reading the data and assigning counts to arrays and Data class

# %% [markdown]
# #### Data Class
# A Data class will be instantiated for each line of the data.  It will then be added to one of two arrays (explained later).

# %%
from collections import OrderedDict

class Data:
    def __init__(self, class_value):
        self.class_value = class_value
        self.data_vars = OrderedDict()

# %% [markdown]
# ### Calculate Information Gain for Each Feature
# The below function can be used to determine the information gain for a given data and hypothesis (passed in as a string - x and y).  Information Gain can be represented as: Infgain(Y|X_K) = H(Y) - H(Y|X_K)

# %%
# Arrays for the Data instances
#     absence_heart_array  : contains all Data instantiations where heart disease is absent
#     presence_heart_array : contains all Data instantiations where heart disease is absent
absence_heart_array = []
presence_heart_array = []
total_data_array = []

# Classify the features according to their type: nominal or continuous
indices_for_nominal = [10, 1, 5, 8, 6, 2, 12]
indices_for_continuous = [0,3,4,7,9,11]
feature_names = ["age", "sex", "chest_pain_type", "resting_blood_pressure", "serum_cholesterol", "fasting_blood_sugar",
                "resting_electrocardiographic_results", "maximum_heart_rate_achieved", "exercise_induced_angina",
                "oldpeak", "slope_peak_exercise", "number_of_major_vessels", "thal", "has_heart_disease"]
features_and_types = OrderedDict()
for feature in feature_names:
    if feature_names.index(feature) in indices_for_continuous:
        features_and_types[feature] = "continuous"
    else:
        features_and_types[feature] = "nominal"

# Process the data and store it in the arrays
data = open('heart.data.txt')
for line in data.readlines():
    feature_value_list = line.split()
    has_heart_disease = int(feature_value_list[-1])
    data = Data(has_heart_disease)
    counter = 0
    feature_dict = OrderedDict()
    for feature in feature_value_list:
        data.data_vars[feature_names[counter]] = float(feature)
        counter += 1
    if has_heart_disease == 2:
        presence_heart_array.append(data)
    elif has_heart_disease == 1:
        absence_heart_array.append(data)
    total_data_array.append(data)

presence_heart_array_num = len(presence_heart_array)
absence_heart_array_num = len(absence_heart_array)
print "✔ Data processed"
print "-----------------"
print "\t" + str(presence_heart_array_num) + " = # Of People with Heart Disease"
print "\t" + str(absence_heart_array_num) + " = # Of People without Heart Disease"
# Out:
# ✔ Data processed
# -----------------
# 	120 = # Of People with Heart Disease
# 	150 = # Of People without Heart Disease

# %% [markdown]
# ### Utility Printer Function to Print out Data
# The below function can be called with a Data object as its input to print out that data objects contents.

# %%
def print_data(data_obj):
    print "_____________"
    for feature in data_obj.data_vars.keys():
        print data_obj.data_vars[feature], ": ", feature

# %%
import math

def compute_info_gain(y, y_values, x, buckets, considered_data):
        
    '''
    if x == "sex":
        print "sex vals!!!"
        for data_point in considered_data:
            print data_point.data_vars["sex"]
        #print "y_values:"
        #print y_values
    '''
    
    
    '''
    if y == "chest_pain_type":
        print "y_values:"
        print y_values
    '''
    
    #print "Calling compute_info_gain with y = "+y+" and x = "+x
    
        
    # Define dicts for the counts
    positive_y_counts = {}
    positive_x_counts = {}
    negative_y_counts = {}
    negative_x_counts = {}
    
    # Get the bucket values
    for bucket in buckets:
        # Convert to string
        s = ""
        for num in list(set(bucket)):
            s += (str(num)+ " ")
        positive_x_counts[s] = 0
        negative_x_counts[s] = 0
    
    
    for val in y_values:
        positive_y_counts[str(float(val))] = 0
        negative_y_counts[str(float(val))] = 0
    
    y_denom = 0
    for data in considered_data:
        y_denom += 1
        has_heart_disease = data.data_vars["has_heart_disease"]
        y_value = data.data_vars[y]
        x_value = data.data_vars[x]
        array_x = []
        array_y = []
        if has_heart_disease == 1:
            # Update all of the negative arrays
            array_x = negative_x_counts
            array_y = negative_y_counts
        elif has_heart_disease == 2:
            # Update all of the positive arrays
            array_x = positive_x_counts
            array_y = positive_y_counts
            
        # Value is not in dictionary yet
        # so set the occurrence for that value to 1
        '''
        if value not in array_y.keys():
            array_y[y_value] = 1 
        # Value is already in dictionary
        # so increase the occurrence count for that value by 1
        else:
            current_count_for_value = array_y[y_value]
            array_y.update({y_value:current_count_for_value+1})
        '''
        for key in array_x.keys():
            if str(x_value)+" " in key:
                current_count_for_value = array_x[key]
                array_x.update({key:current_count_for_value+1})
                
        for key in array_y.keys():
            if str(y_value) in key:
                current_count_for_value = array_y[key]
                array_y.update({key:current_count_for_value+1})

    '''
    y_denom = 0
    
    for data in presence_heart_array:
        y_denom += 1
        value = data.data_vars[y]
        
        # Value is not in dictionary yet
        # so set the occurrence for that value to 1
        if value not in positive_y_counts.keys():
            positive_y_counts[value] = 1 
        # Value is already in dictionary
        # so increase the occurrence count for that value by 1
        else:
            current_count_for_value = positive_y_counts[value]
            positive_y_counts.update({value:current_count_for_value+1})
            
        # Same thing is done for processing x:
        x_value = data.data_vars[x]
        for key in positive_x_counts.keys():
            if str(x_value)+" " in key:
                current_count_for_value = positive_x_counts[key]
                positive_x_counts.update({key:current_count_for_value+1})
            
    
    for data in absence_heart_array:
        y_denom += 1
        value = data.data_vars[y]
        
        # Value is not in dictionary yet
        # so set the occurrence for that value to 1
        if value not in negative_y_counts.keys():
            negative_y_counts[value] = 1 
        # Value is already in dictionary
        # so increase the occurrence count for that value by 1
        else:
            current_count_for_value = negative_y_counts[value]
            negative_y_counts.update({value:current_count_for_value+1})
            
        # Same thing is done for processing x:
        x_value = data.data_vars[x]
        for key in negative_x_counts.keys():
            if str(x_value)+" " in key:
                current_count_for_value = negative_x_counts[key]
                negative_x_counts.update({key:current_count_for_value+1})
                
    '''
    '''
    if x == "sex":
        print "postive_y_counts array"
        print positive_y_counts
        print "negative_y_counts array"
        print negative_y_counts
    '''   
            
    h_of_y = 0
    for count in positive_y_counts.values():
        '''
        if y == "chest_pain_type":
            print "positive_y_count: "+str(count)
        '''
        
        entropy = 0
        if count != 0:
            p = float(float(count)/float(y_denom))
            entropy = -1 * p * (math.log(p, 2))
        h_of_y += entropy
    for count in negative_y_counts.values():

        '''
        if y == "chest_pain_type":
            print "negative_y_count: "+str(count)
        '''
    
        entropy = 0
        if count != 0:
            p = float(float(count)/float(y_denom))
            entropy = -1 * p * (math.log(p, 2))
        h_of_y += entropy
    
    h_of_y_given_x = 0
    for feature_value in positive_x_counts.keys():
        '''
        if x == "sex":
            print "positive_x_counts: "+str(positive_x_counts[feature_value])+" for feature value: "+str(feature_value)
            print "negative_x_counts: "+str(negative_x_counts[feature_value])+" for feature value: "+str(feature_value)        
        '''
        entropy_positive = 0
        entropy_negative = 0
        sum_of_values = positive_x_counts[feature_value] + negative_x_counts[feature_value] 
        fraction = float(float(sum_of_values)/float(y_denom))
        if positive_x_counts[feature_value] != 0:
            p_positive = float(float(positive_x_counts[feature_value])/float(sum_of_values)) 
            entropy_positive = p_positive * (math.log(p_positive, 2))
        if negative_x_counts[feature_value] != 0:
            p_negative = float(float(negative_x_counts[feature_value])/float(sum_of_values)) 
            entropy_negative = p_negative * (math.log(p_negative, 2))
        
        h_of_y_given_x += fraction*(entropy_positive+entropy_negative)
    
    '''
    if x == "sex":
        print "h_of_y:"+str(h_of_y)
        print "h_of_y_given_x:"+str(h_of_y_given_x)
    '''
    
    '''
    if h_of_y_given_x < 0:
        info_gain = h_of_y - (h_of_y_given_x)
        return info_gain
    else:
        info_gain = h_of_y - (-1*h_of_y_given_x)
        return info_gain
    '''
    #print "h of y: ", h_of_y
    #print "h of y given x: ", h_of_y_given_x
    info_gain = h_of_y + h_of_y_given_x
    return info_gain

# %% [markdown]
# ### Utility Function used to generate all of the possible splits
# Credit:  https://stackoverflow.com/questions/19368375/set-partitions-in-python/30134039#30134039

# %%
def partition(collection):
    if len(collection) == 1:
        yield [ collection ]
        return

    first = collection[0]
    for smaller in partition(collection[1:]):
        # insert `first` in each of the subpartition's subsets
        for n, subset in enumerate(smaller):
            yield smaller[:n] + [[ first ] + subset]  + smaller[n+1:]
        # put `first` in its own subset 
        yield [ [ first ] ] + smaller

# %% [markdown]
# ### Determine possible splits
# These will be used for the information gain

# %%
# get_continuous_binary_split(feature):     
#    Gets a feature and splits the data for that feature in all the possible ways to split that
#    data into two buckets.  It returns a dictionary where the key is the number it split on and the
#    value is a list of two lists.  The first element of the list is all of the elements less than
#    the split and the second element of the list is a list of all of the elements greater than or
#    equal to the split.
#    For example:
#           feature = "age"
#           splits_dict = {50: [[20,40,43...],[50,60,61...]], 60: [[57,45,59...],[60,61,63...]]}
def get_continuous_binary_split(feature, considered_data):
    # Ensure the function is being called only with continuous features
    if features_and_types[feature] != "continuous":
        raise ValueError('Error in get_continuous_binary_split: input feature is not continuous.')
        return
    
    # Create a list of the possible splits
    splits = []
    counts_for_feature_values = {}
    
    #print "The Length of the Considered Data: ",len(considered_data)
    
    for data in considered_data:
        feature_value = float(data.data_vars[feature])
        if feature_value not in splits:
            splits.append(feature_value)
        if feature_value not in counts_for_feature_values:
            counts_for_feature_values[feature_value] = 1
        else:
            current = counts_for_feature_values[feature_value]
            counts_for_feature_values[feature_value] = current + 1
    
    # Process the splits and create the less than list and greater than or equal to list for each
    splits_list = []
    for split in splits:
        lt_split_feature_values = []
        gtequal_split_feature_values = []
        for data in considered_data:
            feature_value = float(data.data_vars[feature])
            if feature_value < split:
                lt_split_feature_values.append(feature_value)
            else:
                gtequal_split_feature_values.append(feature_value)
        #if len(lt_split_feature_values) != 0:
        splits_list.append([lt_split_feature_values, gtequal_split_feature_values])
            
    # Generate a list of partition dicts
    # Each list element will be a list of dictionaries
    # The dictionaries will contain the feature_value and the number of times it occurs
    # The list of these dictionaries will be split up by partition
    partitions_and_values = []
    for partition in splits_list:
        split_inclusive = []
        for l in partition:
            set_l = set(l)
            count_dict = {}
            for feature_value in set_l:
                num_of_feature_value_occurrences = counts_for_feature_values[feature_value]
                count_dict[feature_value] = num_of_feature_value_occurrences
            split_inclusive.append(count_dict)
        partitions_and_values.append(split_inclusive)
            
    return partitions_and_values

# %%
import itertools
# get_nominal_split(feature):     
#    Gets a nominal feature and splits the data for that feature in all the possible ways to split that
#    data into every possible number of buckets.  It returns a dictionary where the key is the number it 
#    split on and the value is a list of the lists it generated from the split.  

def split_list(data, n):
    from itertools import combinations, chain
    for splits in combinations(range(1, len(data)), n-1):
        result = []
        prev = None
        for split in chain(splits, [None]):
            result.append(data[prev:split])
            prev = split
        yield result
        
def get_nominal_split(feature, considered_data):
    # Ensure the function is being called only with nominal features
    if features_and_types[feature] != "nominal":
        raise ValueError('Error in get_nominal_split: input feature is not nominal.')
        return
    
    #print "get_nominal_split called with feature: "+feature
    # Determine the unique values for the feature and the counts for the feature_value
    splits = {}
    split_nums = []
    for data in considered_data:
        feature_value = float(data.data_vars[feature])
        if feature_value not in splits:
            split_nums.append(feature_value)
            splits[feature_value] = 1
        else:
            current_num = splits[feature_value]
            splits[feature_value] = current_num+1
    
    #print "possible values for feature:"
    #print split_nums

    # Generate all the possible ways to partition the numbers  
    # possible_partitions is a list of tuples where the first element of the tuple
    # is the kth possible partition and the second element of the tuple is a list
    # of lists of partitions
    possible_partitions = []
    for p in partition(split_nums):
        # Be sure to remove the split where all values are placed in one bucket
        if (len(sorted(p)) != 1) or ((len(sorted(p)) == 1) and (len(split_nums) == 1)):
            possible_partitions.append(sorted(p))
    #print "possible_partitions:"
    #print possible_partitions
                
    # Generate a list of partition dicts
    # Each list element will be a list of dictionaries
    # The dictionaries will contain the feature_value and the number of times it occurs
    # The list of these dictionaries will be split up by partition
    partitions_and_values = []
    for split_lists in possible_partitions:
        split_dicts = []
        for bucket in split_lists:
            bucket_dict = {}
            for feature_value in bucket:
                num_of_feature_value_occurrences = splits[feature_value]
                bucket_dict[feature_value] = num_of_feature_value_occurrences
            split_dicts.append(bucket_dict)
        partitions_and_values.append(split_dicts)
    return partitions_and_values

# %% [markdown]
# ### Compute the best split
# Checks the information gain for all the possible splits for a certain feature and reports the best one.

# %%
def compute_best_split(y, y_values, feature, considered_data):
    # Check if the feature is nominal or continuous and split accordingly
    splits = []
    if features_and_types[feature] == "nominal":
        
        splits = get_nominal_split(feature, considered_data)
    else:
        splits = get_continuous_binary_split(feature, considered_data)
    
    # Create a dictionary where the key is the information gain from a particular
    # split and the value is that particular split
    info_gains = {}
    for split in splits:
        info_gain = compute_info_gain(y, y_values, feature, split, considered_data)
        info_gains[info_gain] = split
        
    # Process the dictionary and determine the highest info gain
    #print "info-gains"
    #print "compute_best_info_gain called with: "+feature
    #print "considered_data"
    #print considered_data
    #print info_gains
    max_info_gain = max(info_gains, key=float)
    split_yielding_max_info_gain = info_gains[max_info_gain]
    
    # Print the maximum info gain and corresponding split
    #print "FEATURE: "+feature
    #print "Greatest Info Gain is: "+str(max_info_gain)
    #print "from split:"
    #for split in split_yielding_max_info_gain:
        #print sorted(set(split))
    return max_info_gain, split_yielding_max_info_gain

# %% [markdown]
# ### Tree Class
# Set up classes for the tree.

# %%
class Node(object):
    def __init__(self, splitting_feature, feature_value, feature_value_occurrence, data):
        self.splitting_feature = splitting_feature
        self.feature_value = feature_value
        self.feature_value_occurrence = feature_value_occurrence
        self.data = data
        self.id = ""
        self.children = []

    def add_child(self, obj):
        self.children.append(obj)
        
    def print_node(self, node):
        print "\t splitting_feature: ", node.splitting_feature
        print "\t feature_value: ", node.feature_value
        print "\t feature_value_occurrence: ", node.feature_value_occurrence
    
    def print_children(self):
        counter = 1
        for child in self.children:
            print counter, ":"
            self.print_node(child)
            counter += 1
    
    def print_node_and_children(self):
        print "*   NODE  *"
        self.print_node(self)
        print "* CHILDREN *"
        self.print_children()
    
    def assign_edges(self, ids):
        for id_key in ids:
            node = id[id_key]
            if self.is_equal(node):
                self.id = id_key
                break
            else:
                unique_id = str(uuid.uuid4())
                self.id = unique_id
                ids[unique_id] = self
                break
        
        # Process the children
        for child in self.children:
            for id_key in ids:
                node = id[id_key]
                if child.is_equal(node):
                    child.id = id_key
                    break
                else:
                    unique_id = str(uuid.uuid4())
                    child.id = unique_id
                    ids[unique_id] = child
                    break
                
        print "Should assign edges here"
        
    def is_equal(self, leaf):
        print "comparing: ", self.splitting_feature, " with: ", leaf.splitting_feature, " and result is: ", (self.splitting_feature == leaf.splitting_feature)
        print "comparing: ", self.feature_value, " with: ", leaf.feature_value," and result is: ", (self.feature_value == leaf.feature_value)
        print "comparing: ", self.feature_value_occurrence, " with: ", leaf.feature_value_occurrence, " and result is: ", (self.feature_value_occurrence == leaf.feature_value_occurrence)
        print "comparing: children and result is: ",  (len(self.children) == len(leaf.children))
        print "comparing data and data: ", (len(self.data) == len(leaf.data))
        print "length of children self: ", len(self.children)
        print "length of children data: ", len(leaf.children)
        if (self.splitting_feature == leaf.splitting_feature) and (self.feature_value == leaf.feature_value) and (self.feature_value_occurrence == leaf.feature_value_occurrence):
            print "returning true for ", self.splitting_feature, " and ", leaf.splitting_feature
            return True
        else:
            return False

# %% [markdown]
# ### Split Data
# Split the data and return a list of arrays of the split data given the feature and the splits

# %%
def split_data(feature, splits, considered_data):
    #print "Splitting data for feature: "+feature
    #print "split is: "
    #print splits
    data = []
    for split in splits:
        data.append([])
    separate_buckets = {}
    for data in considered_data:
        feature_value = float(data.data_vars[feature])
        if feature_value not in separate_buckets.keys():
            new_list = []
            new_list.append(data)
            separate_buckets[feature_value] = new_list
        else:
            current_list = separate_buckets[feature_value]
            current_list.append(data)
            separate_buckets[feature_value] = current_list
        
    #splits = [{3.0: 152}, {6.0: 14}, {7.0: 16}]
    #OR splits = [{3.0: 152}, [{6.0: 14}, {7.0: 16}]]
            
    new_data = []
    for split in splits:
        
        #print "Processing split: ", split
        
        # {0.0: 7}
        # {1.0: 4, 2.0: 2, 3.0: 1}
        
        # Convert it to a list
        split_list = []
        if len(split) == 1:
            
            split_list.append(split)
        else:
            split_list.append(split)
            '''
            for each_value in split:
                print "Appending each value: ", each_value
                split_list.append(each_value)
            '''
        
        # Prepare a list for the data of that split
        data_for_split = []
        
        # Get all the valid feature_values for that particular split
        valid_feature_values = []
        #print "SPLIT LIST IN SPLIT DATA: ", split_list
        for split_dict in split_list:
            for feature_value_key in split_dict.keys():
                valid_feature_values.append(feature_value_key)
        
        # Process the valid feature values, find matching data, and add it to the data for that split
        for feature_value in valid_feature_values:
            for data_pt in separate_buckets[feature_value]:
                data_for_split.append(data_pt)
        
        # Add the data relevant for a certain split group to the new data array
        new_data.append(data_for_split)
        '''
        if feature == "number_of_major_vessels":
            print "Length of data for split: ", len(data_for_split)
            '''
    '''
    if feature == "number_of_major_vessels":
        print "Length of data returned for 1, 2, 3 : ", len(new_data[1])
    '''
    return new_data

# %% [markdown]
# ### Recurse to build the tree
# Used the information gain function to determine the best splits for each node of the tree.

# %%
def build_tree(y, y_values, data, allowable_features_to_split_on):
    info_gains = {}
    split_yielding_max_info_gain = []
    for feature in allowable_features_to_split_on:
        if feature != y:
            info_gain, split_yielding_max_info_gain = compute_best_split(y, y_values, feature, data)
            info_gains[feature] = [info_gain, split_yielding_max_info_gain]

    #print info_gains

    # Printing out the information gains for each feature
    '''
    for feature in info_gains.keys():
        print str(info_gains[feature][0])+" : "+feature
    '''

    # Find the maximum in the info_gains returned
    max_info_gain = 0
    best_split = []
    best_feature = ""
    
    # Check if they are all equal to 0
    counter = 0
    total = 0
    for feature in info_gains.keys():
        if info_gains[feature][0] == 0:
            counter += 1
        total += 1
    if counter == total:
        return
    
    #print info_gains.keys()
    for feature in info_gains.keys():
        if info_gains[feature][0] > max_info_gain:
            max_info_gain = info_gains[feature][0]
            best_split = info_gains[feature][1]
            best_feature = feature

    #print max_info_gain
    #print best_feature
    # Split on that feature and optimal split
    new_data = split_data(best_feature, best_split, data)

    # Define the new y based on this data
    y = feature
    
    #print best_split
    return best_feature, new_data, best_split



    # Now we have to feed that new data into the tree and branch off into the leaves
    # so we have three groups for thal which means it should branch into three leaves:
    # one with 3, one with 6, and one with 7.
    # And recursively continue branching

# %%
y = "has_heart_disease"
allowable_features_to_split_on = data.data_vars.keys()

feature, new_data, best_split = build_tree(y, [2, 1], total_data_array, allowable_features_to_split_on)
levels = []
levels.append([feature, new_data, best_split])
#print best_split
#print "Length of new data ", len(new_data)
possible_y_vals_array = []
for split in best_split:
    new_list = []
    for y_val in split.keys():
        new_list.append(y_val)
    possible_y_vals_array.append(new_list)
    
# Edit the features allowed to split on

'''
for data in new_data[1]:
    print data.data_vars["sex"]
'''

allowable_features_to_split_on.remove("has_heart_disease")
    


tree_array = []
# Process each feature 
# level = [0: feature, 1: new_data, 2: best_split]
new_levels = []
tree_is_finished = False
processed = 0
already_assigned_ids = {}
# splitting_feature, feature_value, feature_value_occurrence, data):
unique_id = str(uuid.uuid4())
node = Node(feature, "has_heart_disease", 270, new_data)
node.id = unique_id
already_assigned_ids[unique_id] = node
while not tree_is_finished:
    
    for level in levels:
        '''
        feature = level[0]
        for level in levels:
            print level[0]
        print "Processing feature: ", level[0]
        new_data = level[1]
        best_split = level[2]
        print "Split is : ", best_split
        print 'Length of New Data',len(new_data)
        '''
        
        

        # Process each split for the feature
        for branch_index in range(len(level[1])):
            
            #for split in level[2]:
            #print "New Node:"
            #print "\t splitting_feature: ", level[0]
            #print "\t feature_value: ", level[2][branch_index].keys()
            #print "\t feature_value_occurrence: ", sum(level[2][branch_index].values())
            current_leaf = Node(level[0], level[2][branch_index].keys(), sum(level[2][branch_index].values()),level[1][branch_index])
            
            # NEW ADDITION
            # Assign the id but first check to see if you've already assigned it
            print "Processing ", current_leaf.splitting_feature
            for assigned_id, assigned_leaf in already_assigned_ids.iteritems():
                print "Checking against: ", assigned_leaf.splitting_feature
                if current_leaf.is_equal(assigned_leaf):
                    current_leaf.id = assigned_id
                    print "ALREADY ASSIGNED IT"
                    print "Keeping the id for ", current_leaf.splitting_feature, " as ", current_leaf.id
                    break
                else:
                    unique_id = str(uuid.uuid4())
                    current_leaf.id = unique_id
                    already_assigned_ids[unique_id] = current_leaf
                    break
            # END NEW ADDITION
            
            tree_array.append(current_leaf)
            
            print "Processing the branch for:"
            print "\t Feature = ", level[0]
            print "\t Split   = ", level[2][branch_index]
            data_for_next_call = level[1][branch_index]
            print "\t Length of New Data   = ", len(data_for_next_call)
            '''
            if len(level[2][branch_index]) > 1:
                data_for_next_call = level[1][branch_index]
                print
            else: 
                print "\t Length of New Data   = ", len(level[1][branch_index][0])
            '''
            # Edit the allowable features to split on since if you split on a nominal feature and only have 
            # one value for that nominal feature in the branch, you shouldn't split on it again
            if features_and_types[feature] == "nominal" and len(possible_y_vals_array[0]) == 1 and level[0] in allowable_features_to_split_on:
                print "Allowable features to split on: ", allowable_features_to_split_on
                print "Trying to remove: ", level[0]
                allowable_features_to_split_on.remove(level[0])
            # Call build_tree for next partition
            #print "Allowable_features_to_split_on:"
            #print allowable_features_to_split_on
            #print "y is : "+feature
            if len(allowable_features_to_split_on) != 0:
                #print "Possible_y_vals:"
                #print possible_y_vals_array
                #print "branch index: "+str(branch_index)


                
                print "Length of the data for the next call: ", len(data_for_next_call)
                if len(data_for_next_call) > 5:

                    possible_y_values = []
                    for pt in data_for_next_call:
                            y_value = pt.data_vars[level[0]]
                            if y_value not in possible_y_values:
                                possible_y_values.append(y_value)

                    #print "Allowable features to split on:"
                    #print allowable_features_to_split_on
                    #print "Level[0]"
                    #print level[0]
                    #print "Possible y values:"
                    #print possible_y_values
                    #print "new data of branch index:"
                    #print new_data[branch_index]

                    '''
                    if level[0] == "chest_pain_type":
                        for data in data_for_next_call:
                            print_data(data)
                    '''

                    next_feature, next_new_data, next_best_split = build_tree(level[0], possible_y_values, data_for_next_call, allowable_features_to_split_on)

                    print "*** Next Feature:"
                    print next_feature
                    #print "*** Next New Data:"
                    #print next_new_data
                    print "*** Next Best Split:"
                    print next_best_split
                    print "*** Length of Next New Data:"
                    print len(next_new_data)

                    # Add the children for the current leaf
                    for child_index in range(len(next_new_data)):
                        child_splitting_feature = next_feature
                        child_feature_value = next_best_split[child_index].keys()
                        child_feature_value_occurrence = sum(next_best_split[child_index].values())
                        child = Node(child_splitting_feature, child_feature_value, child_feature_value_occurrence,next_new_data)
                        
                        # NEW ADDITION
                        # Assign the id but first check to see if you've already assigned it
                        for assigned_id, assigned_leaf in already_assigned_ids.iteritems():
                            if child.is_equal(assigned_leaf):
                                child.id = assigned_id
                                print "GETTING IN HERE"
                                break
                            else:
                                unique_id = str(uuid.uuid4())
                                child.id = unique_id
                                already_assigned_ids[unique_id] = child
                                print "Assigning ", child.splitting_feature, " as ", unique_id
                                break
                        # END NEW ADDITION
                        
                        current_leaf.add_child(child)

                    new_levels.append([next_feature, next_new_data, next_best_split])


                    # Put feature back in allowable features because it's possible we might need it later
                    allowable_features_to_split_on.append(level[0])
                else:
                    print "Skipping call for: ", level[0]
                    print "where split is ", level[2][branch_index]
                    print " and data length is ", len(data_for_next_call)
            #current_leaf.assign_edges()
            current_leaf.print_node_and_children()
        
    # Levels has finished processing
    '''
    for level in levels:
        # Each node is structured:
            # 1. splitting_feature
            # 2. feature_value
            # 3. feature_value_occurrence
        for split in level[2]:
            print "New Node:"
            print "\t splitting_feature: ", level[0]
            print "\t feature_value: ", split.keys()
            print "\t feature_value_occurrence: ", sum(split.values())
            tree_array.append(Node(level[0], split.keys(), split.values()))
    '''
    '''
    for node in tree_array:
        print "new Node:"
        print node.splitting_feature
        print node.feature_value
    '''
    '''
    print "NEW LEVELS:"
    for e in new_levels:
        print "Level: ",e[0]
        print "Length of Data: ",len(e[1])        
        print "Split: ",e[2]
    '''
    del levels[:]
    
    # Set the levels equal to everything in the new_levels
    for s in new_levels:
        levels.append(s)
        
    # Also delete the ones you've processed in new_levels
    
    del levels[0:processed*3]
        
    
    print "ASSIGNING NEW LEVELS"
    for e in levels:
        print "Feature: ", e[0]
        for data_list in e[1]:
            if len(data_list) <= 5:
                print "FLAG "+e[0]+" as finished!!!"
        
    
    processed += 1
    if processed == 3:
        print 
        break
# Out:
# Processing  thal
# Checking against:  thal
# comparing:  thal  with:  thal  and result is:  True
# comparing:  [3.0]  with:  has_heart_disease  and result is:  False
# comparing:  152  with:  270  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  thal
# 	 Split   =  {3.0: 152}
# 	 Length of New Data   =  152
# Allowable features to split on:  ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'number_of_major_vessels', 'thal']
# Trying to remove:  thal
# Length of the data for the next call:  152
# *** Next Feature:
# chest_pain_type
# *** Next Best Split:
# [{1.0: 12}, {2.0: 33}, {3.0: 56}, {4.0: 51}]
# *** Length of Next New Data:
# 4
# comparing:  chest_pain_type  with:  thal  and result is:  False
# comparing:  [1.0]  with:  has_heart_disease  and result is:  False
# comparing:  12  with:  270  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  chest_pain_type  as  cd92d28b-e453-401e-8e4a-655705480b7c
# comparing:  chest_pain_type  with:  thal  and result is:  False
# comparing:  [2.0]  with:  has_heart_disease  and result is:  False
# comparing:  33  with:  270  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  chest_pain_type  as  0c7836e0-7abd-4878-96c9-5f46a6f923e1
# comparing:  chest_pain_type  with:  chest_pain_type  and result is:  True
# comparing:  [3.0]  with:  [2.0]  and result is:  False
# comparing:  56  with:  33  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  chest_pain_type  as  7671d588-a5e0-49a3-9ed8-ead30548cf7f
# comparing:  chest_pain_type  with:  chest_pain_type  and result is:  True
# comparing:  [4.0]  with:  [2.0]  and result is:  False
# comparing:  51  with:  33  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  chest_pain_type  as  9b88e905-688b-439a-a1ff-5b936b8428db
# *   NODE  *
# 	 splitting_feature:  thal
# 	 feature_value:  [3.0]
# 	 feature_value_occurrence:  152
# * CHILDREN *
# 1 :
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [1.0]
# 	 feature_value_occurrence:  12
# 2 :
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [2.0]
# 	 feature_value_occurrence:  33
# 3 :
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [3.0]
# 	 feature_value_occurrence:  56
# 4 :
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [4.0]
# 	 feature_value_occurrence:  51
# Processing  thal
# Checking against:  chest_pain_type
# comparing:  thal  with:  chest_pain_type  and result is:  False
# comparing:  [6.0]  with:  [3.0]  and result is:  False
# comparing:  14  with:  56  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  thal
# 	 Split   =  {6.0: 14}
# 	 Length of New Data   =  14
# Allowable features to split on:  ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'number_of_major_vessels', 'thal']
# Trying to remove:  thal
# Length of the data for the next call:  14
# *** Next Feature:
# number_of_major_vessels
# *** Next Best Split:
# [{0.0: 7}, {1.0: 4, 2.0: 2, 3.0: 1}]
# *** Length of Next New Data:
# 2
# comparing:  number_of_major_vessels  with:  chest_pain_type  and result is:  False
# comparing:  [0.0]  with:  [3.0]  and result is:  False
# comparing:  7  with:  56  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  number_of_major_vessels  as  424661df-b386-4c41-ac73-a65dcd2cc6d2
# comparing:  number_of_major_vessels  with:  chest_pain_type  and result is:  False
# comparing:  [1.0, 2.0, 3.0]  with:  [3.0]  and result is:  False
# comparing:  7  with:  56  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  number_of_major_vessels  as  85c126b4-73ff-48c3-8580-852af8a47fa7
# *   NODE  *
# 	 splitting_feature:  thal
# 	 feature_value:  [6.0]
# 	 feature_value_occurrence:  14
# * CHILDREN *
# 1 :
# 	 splitting_feature:  number_of_major_vessels
# 	 feature_value:  [0.0]
# 	 feature_value_occurrence:  7
# 2 :
# 	 splitting_feature:  number_of_major_vessels
# 	 feature_value:  [1.0, 2.0, 3.0]
# 	 feature_value_occurrence:  7
# Processing  thal
# Checking against:  chest_pain_type
# comparing:  thal  with:  chest_pain_type  and result is:  False
# comparing:  [7.0]  with:  [3.0]  and result is:  False
# comparing:  104  with:  56  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  thal
# 	 Split   =  {7.0: 104}
# 	 Length of New Data   =  104
# Allowable features to split on:  ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'number_of_major_vessels', 'thal']
# Trying to remove:  thal
# Length of the data for the next call:  104
# *** Next Feature:
# chest_pain_type
# *** Next Best Split:
# [{1.0: 6}, {2.0: 7}, {3.0: 21}, {4.0: 70}]
# *** Length of Next New Data:
# 4
# comparing:  chest_pain_type  with:  thal  and result is:  False
# comparing:  [1.0]  with:  [7.0]  and result is:  False
# comparing:  6  with:  104  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  chest_pain_type  as  18eae70f-f1ea-4855-9681-01cb8b17fa16
# comparing:  chest_pain_type  with:  chest_pain_type  and result is:  True
# comparing:  [2.0]  with:  [1.0]  and result is:  False
# comparing:  7  with:  6  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  chest_pain_type  as  ce99f9d9-2766-4e24-b2c8-075af17bdd50
# comparing:  chest_pain_type  with:  chest_pain_type  and result is:  True
# comparing:  [3.0]  with:  [1.0]  and result is:  False
# comparing:  21  with:  6  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  chest_pain_type  as  3d8db481-1f46-42bb-bb0f-a211f67a6b69
# comparing:  chest_pain_type  with:  chest_pain_type  and result is:  True
# comparing:  [4.0]  with:  [1.0]  and result is:  False
# comparing:  70  with:  6  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  chest_pain_type  as  ced2a5bb-227c-4765-9af4-12f3f05fa3ed
# *   NODE  *
# 	 splitting_feature:  thal
# 	 feature_value:  [7.0]
# 	 feature_value_occurrence:  104
# * CHILDREN *
# 1 :
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [1.0]
# 	 feature_value_occurrence:  6
# 2 :
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [2.0]
# 	 feature_value_occurrence:  7
# 3 :
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [3.0]
# 	 feature_value_occurrence:  21
# 4 :
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [4.0]
# 	 feature_value_occurrence:  70
# ASSIGNING NEW LEVELS
# Feature:  chest_pain_type
# Feature:  number_of_major_vessels
# Feature:  chest_pain_type
# Processing  chest_pain_type
# Checking against:  chest_pain_type
# comparing:  chest_pain_type  with:  chest_pain_type  and result is:  True
# comparing:  [1.0]  with:  [1.0]  and result is:  True
# comparing:  12  with:  6  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  chest_pain_type
# 	 Split   =  {1.0: 12}
# 	 Length of New Data   =  12
# Allowable features to split on:  ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'number_of_major_vessels', 'thal']
# Trying to remove:  chest_pain_type
# Length of the data for the next call:  12
# *** Next Feature:
# serum_cholesterol
# *** Next Best Split:
# [{226.0: 1, 234.0: 2, 239.0: 1, 240.0: 1, 211.0: 1, 244.0: 1, 213.0: 1, 182.0: 1}, {273.0: 1, 282.0: 1, 283.0: 1}]
# *** Length of Next New Data:
# 2
# comparing:  serum_cholesterol  with:  chest_pain_type  and result is:  False
# comparing:  [226.0, 234.0, 239.0, 240.0, 211.0, 244.0, 213.0, 182.0]  with:  [1.0]  and result is:  False
# comparing:  9  with:  6  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  serum_cholesterol  as  8e534764-fb8c-4c70-90b6-2227e2288b1c
# comparing:  serum_cholesterol  with:  chest_pain_type  and result is:  False
# comparing:  [273.0, 282.0, 283.0]  with:  [1.0]  and result is:  False
# comparing:  3  with:  6  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  serum_cholesterol  as  c3d32a0c-f614-4f7e-8bce-6d330fc49a6e
# *   NODE  *
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [1.0]
# 	 feature_value_occurrence:  12
# * CHILDREN *
# 1 :
# 	 splitting_feature:  serum_cholesterol
# 	 feature_value:  [226.0, 234.0, 239.0, 240.0, 211.0, 244.0, 213.0, 182.0]
# 	 feature_value_occurrence:  9
# 2 :
# 	 splitting_feature:  serum_cholesterol
# 	 feature_value:  [273.0, 282.0, 283.0]
# 	 feature_value_occurrence:  3
# Processing  chest_pain_type
# Checking against:  chest_pain_type
# comparing:  chest_pain_type  with:  chest_pain_type  and result is:  True
# comparing:  [2.0]  with:  [1.0]  and result is:  False
# comparing:  33  with:  6  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  chest_pain_type
# 	 Split   =  {2.0: 33}
# 	 Length of New Data   =  33
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'number_of_major_vessels', 'thal', 'chest_pain_type']
# Trying to remove:  chest_pain_type
# Length of the data for the next call:  33
# *** Next Feature:
# oldpeak
# *** Next Best Split:
# [{0.0: 19, 0.4: 1, 0.2: 3, 0.8: 2, 0.6: 2, 1.1: 1, 1.3: 1, 0.7: 1, 1.4: 2}, {1.8: 1}]
# *** Length of Next New Data:
# 2
# comparing:  oldpeak  with:  chest_pain_type  and result is:  False
# comparing:  [0.0, 0.4, 0.2, 0.8, 0.6, 1.1, 1.3, 0.7, 1.4]  with:  [1.0]  and result is:  False
# comparing:  32  with:  6  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  oldpeak  as  9bb2d42a-4603-42cb-9eb3-ac13b5e5c32f
# comparing:  oldpeak  with:  chest_pain_type  and result is:  False
# comparing:  [1.8]  with:  [1.0]  and result is:  False
# comparing:  1  with:  6  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  oldpeak  as  3406c177-ba1d-4ce2-bebc-37ea28e80998
# *   NODE  *
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [2.0]
# 	 feature_value_occurrence:  33
# * CHILDREN *
# 1 :
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [0.0, 0.4, 0.2, 0.8, 0.6, 1.1, 1.3, 0.7, 1.4]
# 	 feature_value_occurrence:  32
# 2 :
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [1.8]
# 	 feature_value_occurrence:  1
# Processing  chest_pain_type
# Checking against:  chest_pain_type
# comparing:  chest_pain_type  with:  chest_pain_type  and result is:  True
# comparing:  [3.0]  with:  [1.0]  and result is:  False
# comparing:  56  with:  6  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  chest_pain_type
# 	 Split   =  {3.0: 56}
# 	 Length of New Data   =  56
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'number_of_major_vessels', 'thal', 'chest_pain_type']
# Trying to remove:  chest_pain_type
# Length of the data for the next call:  56
# *** Next Feature:
# maximum_heart_rate_achieved
# *** Next Best Split:
# [{96.0: 1, 130.0: 1, 115.0: 1, 155.0: 1, 137.0: 1, 139.0: 1, 126.0: 1, 142.0: 1, 143.0: 1, 147.0: 1, 116.0: 1, 149.0: 2, 150.0: 1, 151.0: 1, 152.0: 3, 148.0: 1, 123.0: 1, 156.0: 1, 157.0: 3, 158.0: 3}, {160.0: 2, 162.0: 1, 163.0: 2, 165.0: 2, 166.0: 1, 167.0: 1, 168.0: 1, 169.0: 2, 170.0: 2, 172.0: 4, 173.0: 2, 174.0: 1, 175.0: 2, 179.0: 3, 180.0: 1, 182.0: 1, 187.0: 1}]
# *** Length of Next New Data:
# 2
# comparing:  maximum_heart_rate_achieved  with:  chest_pain_type  and result is:  False
# comparing:  [96.0, 130.0, 115.0, 155.0, 137.0, 139.0, 126.0, 142.0, 143.0, 147.0, 116.0, 149.0, 150.0, 151.0, 152.0, 148.0, 123.0, 156.0, 157.0, 158.0]  with:  [1.0]  and result is:  False
# comparing:  27  with:  6  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  maximum_heart_rate_achieved  as  c81977a8-f34c-4275-92d9-9fc7b358447a
# comparing:  maximum_heart_rate_achieved  with:  chest_pain_type  and result is:  False
# comparing:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  with:  [3.0]  and result is:  False
# comparing:  29  with:  56  and result is:  False
# comparing: children and result is:  False
# comparing data and data:  False
# length of children self:  0
# length of children data:  1
# Assigning  maximum_heart_rate_achieved  as  94cd65ed-53c1-41da-aed0-1e9327a75a8a
# *   NODE  *
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [3.0]
# 	 feature_value_occurrence:  56
# * CHILDREN *
# 1 :
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [96.0, 130.0, 115.0, 155.0, 137.0, 139.0, 126.0, 142.0, 143.0, 147.0, 116.0, 149.0, 150.0, 151.0, 152.0, 148.0, 123.0, 156.0, 157.0, 158.0]
# 	 feature_value_occurrence:  27
# 2 :
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]
# 	 feature_value_occurrence:  29
# Processing  chest_pain_type
# Checking against:  maximum_heart_rate_achieved
# comparing:  chest_pain_type  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [4.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  51  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  chest_pain_type
# 	 Split   =  {4.0: 51}
# 	 Length of New Data   =  51
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'number_of_major_vessels', 'thal', 'chest_pain_type']
# Trying to remove:  chest_pain_type
# Length of the data for the next call:  51
# *** Next Feature:
# number_of_major_vessels
# *** Next Best Split:
# [{0.0: 31}, {1.0: 10, 2.0: 6, 3.0: 4}]
# *** Length of Next New Data:
# 2
# comparing:  number_of_major_vessels  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  31  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  number_of_major_vessels  as  c30fa6b2-7edd-482c-bf5e-dd5333369d9f
# comparing:  number_of_major_vessels  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [1.0, 2.0, 3.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  20  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  number_of_major_vessels  as  644dcbf0-0189-4afa-8386-611b426b1c8b
# *   NODE  *
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [4.0]
# 	 feature_value_occurrence:  51
# * CHILDREN *
# 1 :
# 	 splitting_feature:  number_of_major_vessels
# 	 feature_value:  [0.0]
# 	 feature_value_occurrence:  31
# 2 :
# 	 splitting_feature:  number_of_major_vessels
# 	 feature_value:  [1.0, 2.0, 3.0]
# 	 feature_value_occurrence:  20
# Processing  number_of_major_vessels
# Checking against:  maximum_heart_rate_achieved
# comparing:  number_of_major_vessels  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  7  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  number_of_major_vessels
# 	 Split   =  {0.0: 7}
# 	 Length of New Data   =  7
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'number_of_major_vessels', 'thal', 'chest_pain_type']
# Trying to remove:  number_of_major_vessels
# Length of the data for the next call:  7
# *** Next Feature:
# maximum_heart_rate_achieved
# *** Next Best Split:
# [{125.0: 1}, {132.0: 1, 138.0: 1, 148.0: 1, 190.0: 1, 150.0: 1, 126.0: 1}]
# *** Length of Next New Data:
# 2
# comparing:  maximum_heart_rate_achieved  with:  maximum_heart_rate_achieved  and result is:  True
# comparing:  [125.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  1  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  maximum_heart_rate_achieved  as  5f9cb1f5-23f7-474c-a6ae-1ecde6bae1e5
# comparing:  maximum_heart_rate_achieved  with:  maximum_heart_rate_achieved  and result is:  True
# comparing:  [132.0, 138.0, 148.0, 190.0, 150.0, 126.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  6  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  maximum_heart_rate_achieved  as  36f187cb-5644-4878-a599-525f4e0a10c0
# *   NODE  *
# 	 splitting_feature:  number_of_major_vessels
# 	 feature_value:  [0.0]
# 	 feature_value_occurrence:  7
# * CHILDREN *
# 1 :
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [125.0]
# 	 feature_value_occurrence:  1
# 2 :
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [132.0, 138.0, 148.0, 190.0, 150.0, 126.0]
# 	 feature_value_occurrence:  6
# Processing  number_of_major_vessels
# Checking against:  maximum_heart_rate_achieved
# comparing:  number_of_major_vessels  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [1.0, 2.0, 3.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  7  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  number_of_major_vessels
# 	 Split   =  {1.0: 4, 2.0: 2, 3.0: 1}
# 	 Length of New Data   =  7
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'thal', 'chest_pain_type', 'number_of_major_vessels']
# Trying to remove:  number_of_major_vessels
# Length of the data for the next call:  7
# *** Next Feature:
# maximum_heart_rate_achieved
# *** Next Best Split:
# [{112.0: 1, 105.0: 1}, {120.0: 1, 132.0: 1, 142.0: 1, 134.0: 1, 158.0: 1}]
# *** Length of Next New Data:
# 2
# comparing:  maximum_heart_rate_achieved  with:  maximum_heart_rate_achieved  and result is:  True
# comparing:  [112.0, 105.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  2  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  maximum_heart_rate_achieved  as  daf061e2-1743-4511-9288-160447e13169
# comparing:  maximum_heart_rate_achieved  with:  maximum_heart_rate_achieved  and result is:  True
# comparing:  [120.0, 132.0, 142.0, 134.0, 158.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  5  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  maximum_heart_rate_achieved  as  100801c9-d26c-4362-bcec-d0181cd4d83c
# *   NODE  *
# 	 splitting_feature:  number_of_major_vessels
# 	 feature_value:  [1.0, 2.0, 3.0]
# 	 feature_value_occurrence:  7
# * CHILDREN *
# 1 :
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [112.0, 105.0]
# 	 feature_value_occurrence:  2
# 2 :
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [120.0, 132.0, 142.0, 134.0, 158.0]
# 	 feature_value_occurrence:  5
# Processing  chest_pain_type
# Checking against:  maximum_heart_rate_achieved
# comparing:  chest_pain_type  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [1.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  6  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  chest_pain_type
# 	 Split   =  {1.0: 6}
# 	 Length of New Data   =  6
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'thal', 'chest_pain_type', 'number_of_major_vessels']
# Trying to remove:  chest_pain_type
# Length of the data for the next call:  6
# *** Next Feature:
# maximum_heart_rate_achieved
# *** Next Best Split:
# [{145.0: 1, 178.0: 2, 162.0: 1, 159.0: 1}, {182.0: 1}]
# *** Length of Next New Data:
# 2
# comparing:  maximum_heart_rate_achieved  with:  maximum_heart_rate_achieved  and result is:  True
# comparing:  [145.0, 178.0, 162.0, 159.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  5  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  maximum_heart_rate_achieved  as  33c3badd-5ba6-400c-8775-2e47b72f11b5
# comparing:  maximum_heart_rate_achieved  with:  maximum_heart_rate_achieved  and result is:  True
# comparing:  [182.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  1  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  maximum_heart_rate_achieved  as  a0c922f0-3c60-454c-8403-57a155e59a54
# *   NODE  *
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [1.0]
# 	 feature_value_occurrence:  6
# * CHILDREN *
# 1 :
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [145.0, 178.0, 162.0, 159.0]
# 	 feature_value_occurrence:  5
# 2 :
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [182.0]
# 	 feature_value_occurrence:  1
# Processing  chest_pain_type
# Checking against:  maximum_heart_rate_achieved
# comparing:  chest_pain_type  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [2.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  7  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  chest_pain_type
# 	 Split   =  {2.0: 7}
# 	 Length of New Data   =  7
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'thal', 'number_of_major_vessels', 'chest_pain_type']
# Trying to remove:  chest_pain_type
# Length of the data for the next call:  7
# *** Next Feature:
# oldpeak
# *** Next Best Split:
# [{0.0: 4}, {1.4: 1, 0.3: 1, 1.0: 1}]
# *** Length of Next New Data:
# 2
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  4  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  oldpeak  as  080da109-b853-4555-a59e-0db10821cb04
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [1.4, 0.3, 1.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  3  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  oldpeak  as  949ea4f9-9550-44db-be9f-5ced96ad77bd
# *   NODE  *
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [2.0]
# 	 feature_value_occurrence:  7
# * CHILDREN *
# 1 :
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [0.0]
# 	 feature_value_occurrence:  4
# 2 :
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [1.4, 0.3, 1.0]
# 	 feature_value_occurrence:  3
# Processing  chest_pain_type
# Checking against:  maximum_heart_rate_achieved
# comparing:  chest_pain_type  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [3.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  21  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  chest_pain_type
# 	 Split   =  {3.0: 21}
# 	 Length of New Data   =  21
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'thal', 'number_of_major_vessels', 'chest_pain_type']
# Trying to remove:  chest_pain_type
# Length of the data for the next call:  21
# *** Next Feature:
# oldpeak
# *** Next Best Split:
# [{0.0: 1, 1.0: 1, 0.2: 2, 1.6: 3, 0.4: 2, 0.6: 2, 1.2: 1, 0.8: 1, 1.8: 2, 0.5: 1}, {2.5: 1, 2.0: 2, 2.9: 1, 3.2: 1}]
# *** Length of Next New Data:
# 2
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0, 1.0, 0.2, 1.6, 0.4, 0.6, 1.2, 0.8, 1.8, 0.5]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  16  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  oldpeak  as  5d878a23-85df-498d-943d-42ff455cf752
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [2.5, 2.0, 2.9, 3.2]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  5  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  oldpeak  as  e2e90e78-d567-4b3c-a16c-552ace6ec853
# *   NODE  *
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [3.0]
# 	 feature_value_occurrence:  21
# * CHILDREN *
# 1 :
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [0.0, 1.0, 0.2, 1.6, 0.4, 0.6, 1.2, 0.8, 1.8, 0.5]
# 	 feature_value_occurrence:  16
# 2 :
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [2.5, 2.0, 2.9, 3.2]
# 	 feature_value_occurrence:  5
# Processing  chest_pain_type
# Checking against:  maximum_heart_rate_achieved
# comparing:  chest_pain_type  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [4.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  70  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  chest_pain_type
# 	 Split   =  {4.0: 70}
# 	 Length of New Data   =  70
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'thal', 'number_of_major_vessels', 'chest_pain_type']
# Trying to remove:  chest_pain_type
# Length of the data for the next call:  70
# *** Next Feature:
# oldpeak
# *** Next Best Split:
# [{0.5: 2, 0.0: 11, 0.2: 2, 0.4: 1, 0.1: 2}, {2.5: 1, 1.0: 5, 2.0: 3, 3.0: 2, 4.0: 2, 1.9: 2, 4.2: 1, 2.8: 4, 5.6: 1, 3.4: 1, 3.6: 1, 0.9: 1, 6.2: 1, 1.2: 6, 2.4: 1, 0.8: 3, 1.4: 4, 2.2: 2, 1.6: 3, 1.8: 3, 2.6: 4, 3.1: 1}]
# *** Length of Next New Data:
# 2
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.5, 0.0, 0.2, 0.4, 0.1]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  18  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  oldpeak  as  c30a2a97-cf26-4473-a01d-01c8e51b01a6
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [2.5, 1.0, 2.0, 3.0, 4.0, 1.9, 4.2, 2.8, 5.6, 3.4, 3.6, 0.9, 6.2, 1.2, 2.4, 0.8, 1.4, 2.2, 1.6, 1.8, 2.6, 3.1]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  52  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  oldpeak  as  d358dc1b-8928-4cf1-b187-259088c0e682
# *   NODE  *
# 	 splitting_feature:  chest_pain_type
# 	 feature_value:  [4.0]
# 	 feature_value_occurrence:  70
# * CHILDREN *
# 1 :
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [0.5, 0.0, 0.2, 0.4, 0.1]
# 	 feature_value_occurrence:  18
# 2 :
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [2.5, 1.0, 2.0, 3.0, 4.0, 1.9, 4.2, 2.8, 5.6, 3.4, 3.6, 0.9, 6.2, 1.2, 2.4, 0.8, 1.4, 2.2, 1.6, 1.8, 2.6, 3.1]
# 	 feature_value_occurrence:  52
# ASSIGNING NEW LEVELS
# Feature:  serum_cholesterol
# FLAG serum_cholesterol as finished!!!
# Feature:  oldpeak
# FLAG oldpeak as finished!!!
# Feature:  maximum_heart_rate_achieved
# Feature:  number_of_major_vessels
# Feature:  maximum_heart_rate_achieved
# FLAG maximum_heart_rate_achieved as finished!!!
# Feature:  maximum_heart_rate_achieved
# FLAG maximum_heart_rate_achieved as finished!!!
# FLAG maximum_heart_rate_achieved as finished!!!
# Feature:  maximum_heart_rate_achieved
# FLAG maximum_heart_rate_achieved as finished!!!
# FLAG maximum_heart_rate_achieved as finished!!!
# Feature:  oldpeak
# FLAG oldpeak as finished!!!
# FLAG oldpeak as finished!!!
# Feature:  oldpeak
# FLAG oldpeak as finished!!!
# Feature:  oldpeak
# Processing  serum_cholesterol
# Checking against:  maximum_heart_rate_achieved
# comparing:  serum_cholesterol  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [226.0, 234.0, 239.0, 240.0, 211.0, 244.0, 213.0, 182.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  9  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  serum_cholesterol
# 	 Split   =  {226.0: 1, 234.0: 2, 239.0: 1, 240.0: 1, 211.0: 1, 244.0: 1, 213.0: 1, 182.0: 1}
# 	 Length of New Data   =  9
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'serum_cholesterol', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'thal', 'number_of_major_vessels', 'chest_pain_type']
# Trying to remove:  serum_cholesterol
# Length of the data for the next call:  9
# *** Next Feature:
# oldpeak
# *** Next Best Split:
# [{0.0: 1, 0.1: 1, 0.8: 1, 1.8: 2, 0.9: 1, 1.4: 1}, {2.6: 2}]
# *** Length of Next New Data:
# 2
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0, 0.1, 0.8, 1.8, 0.9, 1.4]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  7  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  oldpeak  as  6240df0e-75b3-476a-aad8-e9963b5e5f9f
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [2.6]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  2  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  oldpeak  as  50648236-0466-4d84-8ca8-efc23f602416
# *   NODE  *
# 	 splitting_feature:  serum_cholesterol
# 	 feature_value:  [226.0, 234.0, 239.0, 240.0, 211.0, 244.0, 213.0, 182.0]
# 	 feature_value_occurrence:  9
# * CHILDREN *
# 1 :
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [0.0, 0.1, 0.8, 1.8, 0.9, 1.4]
# 	 feature_value_occurrence:  7
# 2 :
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [2.6]
# 	 feature_value_occurrence:  2
# Processing  serum_cholesterol
# Checking against:  maximum_heart_rate_achieved
# comparing:  serum_cholesterol  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [273.0, 282.0, 283.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  3  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  serum_cholesterol
# 	 Split   =  {273.0: 1, 282.0: 1, 283.0: 1}
# 	 Length of New Data   =  3
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'thal', 'number_of_major_vessels', 'chest_pain_type', 'serum_cholesterol']
# Trying to remove:  serum_cholesterol
# Length of the data for the next call:  3
# Skipping call for:  serum_cholesterol
# where split is  {273.0: 1, 282.0: 1, 283.0: 1}
#  and data length is  3
# *   NODE  *
# 	 splitting_feature:  serum_cholesterol
# 	 feature_value:  [273.0, 282.0, 283.0]
# 	 feature_value_occurrence:  3
# * CHILDREN *
# Processing  oldpeak
# Checking against:  maximum_heart_rate_achieved
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0, 0.4, 0.2, 0.8, 0.6, 1.1, 1.3, 0.7, 1.4]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  32  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  oldpeak
# 	 Split   =  {0.0: 19, 0.4: 1, 0.2: 3, 0.8: 2, 0.6: 2, 1.1: 1, 1.3: 1, 0.7: 1, 1.4: 2}
# 	 Length of New Data   =  32
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak', 'slope_peak_exercise', 'thal', 'number_of_major_vessels', 'chest_pain_type']
# Trying to remove:  oldpeak
# Length of the data for the next call:  32
# *** Next Feature:
# number_of_major_vessels
# *** Next Best Split:
# [{0.0: 25, 1.0: 4}, {2.0: 3}]
# *** Length of Next New Data:
# 2
# comparing:  number_of_major_vessels  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0, 1.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  29  with:  29  and result is:  True
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  number_of_major_vessels  as  07fad1d2-081e-448f-90c6-c6d6a5b9d7af
# comparing:  number_of_major_vessels  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [2.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  3  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  number_of_major_vessels  as  e50387c7-d5db-4745-9de8-a19bb7a727ab
# *   NODE  *
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [0.0, 0.4, 0.2, 0.8, 0.6, 1.1, 1.3, 0.7, 1.4]
# 	 feature_value_occurrence:  32
# * CHILDREN *
# 1 :
# 	 splitting_feature:  number_of_major_vessels
# 	 feature_value:  [0.0, 1.0]
# 	 feature_value_occurrence:  29
# 2 :
# 	 splitting_feature:  number_of_major_vessels
# 	 feature_value:  [2.0]
# 	 feature_value_occurrence:  3
# Processing  oldpeak
# Checking against:  maximum_heart_rate_achieved
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [1.8]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  1  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  oldpeak
# 	 Split   =  {1.8: 1}
# 	 Length of New Data   =  1
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'slope_peak_exercise', 'thal', 'number_of_major_vessels', 'chest_pain_type', 'oldpeak']
# Trying to remove:  oldpeak
# Length of the data for the next call:  1
# Skipping call for:  oldpeak
# where split is  {1.8: 1}
#  and data length is  1
# *   NODE  *
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [1.8]
# 	 feature_value_occurrence:  1
# * CHILDREN *
# Processing  maximum_heart_rate_achieved
# Checking against:  maximum_heart_rate_achieved
# comparing:  maximum_heart_rate_achieved  with:  maximum_heart_rate_achieved  and result is:  True
# comparing:  [96.0, 130.0, 115.0, 155.0, 137.0, 139.0, 126.0, 142.0, 143.0, 147.0, 116.0, 149.0, 150.0, 151.0, 152.0, 148.0, 123.0, 156.0, 157.0, 158.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  27  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  maximum_heart_rate_achieved
# 	 Split   =  {96.0: 1, 130.0: 1, 115.0: 1, 155.0: 1, 137.0: 1, 139.0: 1, 126.0: 1, 142.0: 1, 143.0: 1, 147.0: 1, 116.0: 1, 149.0: 2, 150.0: 1, 151.0: 1, 152.0: 3, 148.0: 1, 123.0: 1, 156.0: 1, 157.0: 3, 158.0: 3}
# 	 Length of New Data   =  27
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'maximum_heart_rate_achieved', 'exercise_induced_angina', 'slope_peak_exercise', 'thal', 'number_of_major_vessels', 'chest_pain_type']
# Trying to remove:  maximum_heart_rate_achieved
# Length of the data for the next call:  27
# *** Next Feature:
# sex
# *** Next Best Split:
# [{0.0: 14}, {1.0: 13}]
# *** Length of Next New Data:
# 2
# comparing:  sex  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  14  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  sex  as  77d4fa3e-0c72-4b50-8a2e-2b303dcd2039
# comparing:  sex  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [1.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  13  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  sex  as  6e530ae0-0d91-4756-ab04-c29adbd7fa4e
# *   NODE  *
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [96.0, 130.0, 115.0, 155.0, 137.0, 139.0, 126.0, 142.0, 143.0, 147.0, 116.0, 149.0, 150.0, 151.0, 152.0, 148.0, 123.0, 156.0, 157.0, 158.0]
# 	 feature_value_occurrence:  27
# * CHILDREN *
# 1 :
# 	 splitting_feature:  sex
# 	 feature_value:  [0.0]
# 	 feature_value_occurrence:  14
# 2 :
# 	 splitting_feature:  sex
# 	 feature_value:  [1.0]
# 	 feature_value_occurrence:  13
# Processing  maximum_heart_rate_achieved
# Checking against:  maximum_heart_rate_achieved
# comparing:  maximum_heart_rate_achieved  with:  maximum_heart_rate_achieved  and result is:  True
# comparing:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  True
# comparing:  29  with:  29  and result is:  True
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# returning true for  maximum_heart_rate_achieved  and  maximum_heart_rate_achieved
# ALREADY ASSIGNED IT
# Keeping the id for  maximum_heart_rate_achieved  as  94cd65ed-53c1-41da-aed0-1e9327a75a8a
# Processing the branch for:
# 	 Feature =  maximum_heart_rate_achieved
# 	 Split   =  {160.0: 2, 162.0: 1, 163.0: 2, 165.0: 2, 166.0: 1, 167.0: 1, 168.0: 1, 169.0: 2, 170.0: 2, 172.0: 4, 173.0: 2, 174.0: 1, 175.0: 2, 179.0: 3, 180.0: 1, 182.0: 1, 187.0: 1}
# 	 Length of New Data   =  29
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'exercise_induced_angina', 'slope_peak_exercise', 'thal', 'number_of_major_vessels', 'chest_pain_type', 'maximum_heart_rate_achieved']
# Trying to remove:  maximum_heart_rate_achieved
# Length of the data for the next call:  29
# *** Next Feature:
# exercise_induced_angina
# *** Next Best Split:
# [{0.0: 26}, {1.0: 3}]
# *** Length of Next New Data:
# 2
# comparing:  exercise_induced_angina  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  26  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  exercise_induced_angina  as  7f4a388e-4b2d-46a1-8cd9-1c85506581c7
# comparing:  exercise_induced_angina  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [1.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  3  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  exercise_induced_angina  as  4c132d32-801e-4b7e-8d1e-5c52a6e3cbb1
# *   NODE  *
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]
# 	 feature_value_occurrence:  29
# * CHILDREN *
# 1 :
# 	 splitting_feature:  exercise_induced_angina
# 	 feature_value:  [0.0]
# 	 feature_value_occurrence:  26
# 2 :
# 	 splitting_feature:  exercise_induced_angina
# 	 feature_value:  [1.0]
# 	 feature_value_occurrence:  3
# Processing  number_of_major_vessels
# Checking against:  maximum_heart_rate_achieved
# ...
# comparing:  [112.0, 105.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  2  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  maximum_heart_rate_achieved
# 	 Split   =  {112.0: 1, 105.0: 1}
# 	 Length of New Data   =  2
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'exercise_induced_angina', 'slope_peak_exercise', 'thal', 'chest_pain_type', 'number_of_major_vessels', 'maximum_heart_rate_achieved']
# Trying to remove:  maximum_heart_rate_achieved
# Length of the data for the next call:  2
# Skipping call for:  maximum_heart_rate_achieved
# where split is  {112.0: 1, 105.0: 1}
#  and data length is  2
# *   NODE  *
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [112.0, 105.0]
# 	 feature_value_occurrence:  2
# * CHILDREN *
# Processing  maximum_heart_rate_achieved
# Checking against:  maximum_heart_rate_achieved
# comparing:  maximum_heart_rate_achieved  with:  maximum_heart_rate_achieved  and result is:  True
# comparing:  [120.0, 132.0, 142.0, 134.0, 158.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  5  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  maximum_heart_rate_achieved
# 	 Split   =  {120.0: 1, 132.0: 1, 142.0: 1, 134.0: 1, 158.0: 1}
# 	 Length of New Data   =  5
# Length of the data for the next call:  5
# Skipping call for:  maximum_heart_rate_achieved
# where split is  {120.0: 1, 132.0: 1, 142.0: 1, 134.0: 1, 158.0: 1}
#  and data length is  5
# *   NODE  *
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [120.0, 132.0, 142.0, 134.0, 158.0]
# 	 feature_value_occurrence:  5
# * CHILDREN *
# Processing  maximum_heart_rate_achieved
# Checking against:  maximum_heart_rate_achieved
# comparing:  maximum_heart_rate_achieved  with:  maximum_heart_rate_achieved  and result is:  True
# comparing:  [145.0, 178.0, 162.0, 159.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  5  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  maximum_heart_rate_achieved
# 	 Split   =  {145.0: 1, 178.0: 2, 162.0: 1, 159.0: 1}
# 	 Length of New Data   =  5
# Length of the data for the next call:  5
# Skipping call for:  maximum_heart_rate_achieved
# where split is  {145.0: 1, 178.0: 2, 162.0: 1, 159.0: 1}
#  and data length is  5
# *   NODE  *
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [145.0, 178.0, 162.0, 159.0]
# 	 feature_value_occurrence:  5
# * CHILDREN *
# Processing  maximum_heart_rate_achieved
# Checking against:  maximum_heart_rate_achieved
# comparing:  maximum_heart_rate_achieved  with:  maximum_heart_rate_achieved  and result is:  True
# comparing:  [182.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  1  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  maximum_heart_rate_achieved
# 	 Split   =  {182.0: 1}
# 	 Length of New Data   =  1
# Length of the data for the next call:  1
# Skipping call for:  maximum_heart_rate_achieved
# where split is  {182.0: 1}
#  and data length is  1
# *   NODE  *
# 	 splitting_feature:  maximum_heart_rate_achieved
# 	 feature_value:  [182.0]
# 	 feature_value_occurrence:  1
# * CHILDREN *
# Processing  oldpeak
# Checking against:  maximum_heart_rate_achieved
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  4  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  oldpeak
# 	 Split   =  {0.0: 4}
# 	 Length of New Data   =  4
# Length of the data for the next call:  4
# Skipping call for:  oldpeak
# where split is  {0.0: 4}
#  and data length is  4
# *   NODE  *
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [0.0]
# 	 feature_value_occurrence:  4
# * CHILDREN *
# Processing  oldpeak
# Checking against:  maximum_heart_rate_achieved
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [1.4, 0.3, 1.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  3  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  oldpeak
# 	 Split   =  {1.4: 1, 0.3: 1, 1.0: 1}
# 	 Length of New Data   =  3
# Length of the data for the next call:  3
# Skipping call for:  oldpeak
# where split is  {1.4: 1, 0.3: 1, 1.0: 1}
#  and data length is  3
# *   NODE  *
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [1.4, 0.3, 1.0]
# 	 feature_value_occurrence:  3
# * CHILDREN *
# Processing  oldpeak
# Checking against:  maximum_heart_rate_achieved
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0, 1.0, 0.2, 1.6, 0.4, 0.6, 1.2, 0.8, 1.8, 0.5]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  16  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  oldpeak
# 	 Split   =  {0.0: 1, 1.0: 1, 0.2: 2, 1.6: 3, 0.4: 2, 0.6: 2, 1.2: 1, 0.8: 1, 1.8: 2, 0.5: 1}
# 	 Length of New Data   =  16
# Length of the data for the next call:  16
# *** Next Feature:
# slope_peak_exercise
# *** Next Best Split:
# [{1.0: 6}, {2.0: 9}, {3.0: 1}]
# *** Length of Next New Data:
# 3
# comparing:  slope_peak_exercise  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [1.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  6  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  slope_peak_exercise  as  2c451ced-3bfa-4891-bcd8-004da23af22d
# comparing:  slope_peak_exercise  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [2.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  9  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  slope_peak_exercise  as  f5e056b9-037d-454f-bf54-e7f40b19bb90
# comparing:  slope_peak_exercise  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [3.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  1  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Assigning  slope_peak_exercise  as  98c93356-797f-4111-a16b-9e95ce07a121
# *   NODE  *
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [0.0, 1.0, 0.2, 1.6, 0.4, 0.6, 1.2, 0.8, 1.8, 0.5]
# 	 feature_value_occurrence:  16
# * CHILDREN *
# 1 :
# 	 splitting_feature:  slope_peak_exercise
# 	 feature_value:  [1.0]
# 	 feature_value_occurrence:  6
# 2 :
# 	 splitting_feature:  slope_peak_exercise
# 	 feature_value:  [2.0]
# 	 feature_value_occurrence:  9
# 3 :
# 	 splitting_feature:  slope_peak_exercise
# 	 feature_value:  [3.0]
# 	 feature_value_occurrence:  1
# Processing  oldpeak
# Checking against:  maximum_heart_rate_achieved
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [2.5, 2.0, 2.9, 3.2]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  5  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  oldpeak
# 	 Split   =  {2.5: 1, 2.0: 2, 2.9: 1, 3.2: 1}
# 	 Length of New Data   =  5
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'exercise_induced_angina', 'slope_peak_exercise', 'thal', 'chest_pain_type', 'number_of_major_vessels', 'oldpeak']
# Trying to remove:  oldpeak
# Length of the data for the next call:  5
# Skipping call for:  oldpeak
# where split is  {2.5: 1, 2.0: 2, 2.9: 1, 3.2: 1}
#  and data length is  5
# *   NODE  *
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [2.5, 2.0, 2.9, 3.2]
# 	 feature_value_occurrence:  5
# * CHILDREN *
# Processing  oldpeak
# Checking against:  maximum_heart_rate_achieved
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.5, 0.0, 0.2, 0.4, 0.1]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  18  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  oldpeak
# 	 Split   =  {0.5: 2, 0.0: 11, 0.2: 2, 0.4: 1, 0.1: 2}
# 	 Length of New Data   =  18
# Length of the data for the next call:  18
# *** Next Feature:
# age
# *** Next Best Split:
# [{40.0: 1, 41.0: 1, 35.0: 1}, {64.0: 1, 65.0: 1, 67.0: 1, 43.0: 1, 45.0: 1, 48.0: 2, 52.0: 2, 53.0: 1, 57.0: 1, 58.0: 2, 59.0: 2}]
# *** Length of Next New Data:
# 2
# comparing:  age  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [40.0, 41.0, 35.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  3  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  age  as  0f7bd915-5252-4887-9027-c79e48f27bc1
# comparing:  age  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [64.0, 65.0, 67.0, 43.0, 45.0, 48.0, 52.0, 53.0, 57.0, 58.0, 59.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  15  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  age  as  c8794dfe-7e32-47f9-a1e2-ec92a8269f45
# *   NODE  *
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [0.5, 0.0, 0.2, 0.4, 0.1]
# 	 feature_value_occurrence:  18
# * CHILDREN *
# 1 :
# 	 splitting_feature:  age
# 	 feature_value:  [40.0, 41.0, 35.0]
# 	 feature_value_occurrence:  3
# 2 :
# 	 splitting_feature:  age
# 	 feature_value:  [64.0, 65.0, 67.0, 43.0, 45.0, 48.0, 52.0, 53.0, 57.0, 58.0, 59.0]
# 	 feature_value_occurrence:  15
# Processing  oldpeak
# Checking against:  maximum_heart_rate_achieved
# comparing:  oldpeak  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [2.5, 1.0, 2.0, 3.0, 4.0, 1.9, 4.2, 2.8, 5.6, 3.4, 3.6, 0.9, 6.2, 1.2, 2.4, 0.8, 1.4, 2.2, 1.6, 1.8, 2.6, 3.1]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  52  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  False
# length of children self:  0
# length of children data:  0
# Processing the branch for:
# 	 Feature =  oldpeak
# 	 Split   =  {2.5: 1, 1.0: 5, 2.0: 3, 3.0: 2, 4.0: 2, 1.9: 2, 4.2: 1, 2.8: 4, 5.6: 1, 3.4: 1, 3.6: 1, 0.9: 1, 6.2: 1, 1.2: 6, 2.4: 1, 0.8: 3, 1.4: 4, 2.2: 2, 1.6: 3, 1.8: 3, 2.6: 4, 3.1: 1}
# 	 Length of New Data   =  52
# Allowable features to split on:  ['age', 'sex', 'resting_blood_pressure', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'exercise_induced_angina', 'slope_peak_exercise', 'thal', 'chest_pain_type', 'number_of_major_vessels', 'oldpeak']
# Trying to remove:  oldpeak
# Length of the data for the next call:  52
# *** Next Feature:
# exercise_induced_angina
# *** Next Best Split:
# [{0.0: 14}, {1.0: 38}]
# *** Length of Next New Data:
# 2
# comparing:  exercise_induced_angina  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [0.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  14  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  exercise_induced_angina  as  1ef42230-2ce9-4fd2-904a-2c18e2b5cbe7
# comparing:  exercise_induced_angina  with:  maximum_heart_rate_achieved  and result is:  False
# comparing:  [1.0]  with:  [160.0, 162.0, 163.0, 165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 172.0, 173.0, 174.0, 175.0, 179.0, 180.0, 182.0, 187.0]  and result is:  False
# comparing:  38  with:  29  and result is:  False
# comparing: children and result is:  True
# comparing data and data:  True
# length of children self:  0
# length of children data:  0
# Assigning  exercise_induced_angina  as  8e70a643-b9c8-4a1d-b4aa-7f5f8dafef38
# *   NODE  *
# 	 splitting_feature:  oldpeak
# 	 feature_value:  [2.5, 1.0, 2.0, 3.0, 4.0, 1.9, 4.2, 2.8, 5.6, 3.4, 3.6, 0.9, 6.2, 1.2, 2.4, 0.8, 1.4, 2.2, 1.6, 1.8, 2.6, 3.1]
# 	 feature_value_occurrence:  52
# * CHILDREN *
# 1 :
# 	 splitting_feature:  exercise_induced_angina
# 	 feature_value:  [0.0]
# 	 feature_value_occurrence:  14
# 2 :
# 	 splitting_feature:  exercise_induced_angina
# 	 feature_value:  [1.0]
# 	 feature_value_occurrence:  38
# ASSIGNING NEW LEVELS
# Feature:  number_of_major_vessels
# Feature:  maximum_heart_rate_achieved
# FLAG maximum_heart_rate_achieved as finished!!!
# Feature:  maximum_heart_rate_achieved
# FLAG maximum_heart_rate_achieved as finished!!!
# FLAG maximum_heart_rate_achieved as finished!!!
# Feature:  maximum_heart_rate_achieved
# FLAG maximum_heart_rate_achieved as finished!!!
# FLAG maximum_heart_rate_achieved as finished!!!
# Feature:  oldpeak
# FLAG oldpeak as finished!!!
# FLAG oldpeak as finished!!!
# Feature:  oldpeak
# FLAG oldpeak as finished!!!
# Feature:  oldpeak
# Feature:  oldpeak
# FLAG oldpeak as finished!!!
# Feature:  number_of_major_vessels
# FLAG number_of_major_vessels as finished!!!
# Feature:  sex
# Feature:  exercise_induced_angina
# FLAG exercise_induced_angina as finished!!!
# Feature:  age
# Feature:  sex
# Feature:  exercise_induced_angina
# FLAG exercise_induced_angina as finished!!!
# FLAG exercise_induced_angina as finished!!!
# Feature:  slope_peak_exercise
# FLAG slope_peak_exercise as finished!!!
# Feature:  age
# FLAG age as finished!!!
# Feature:  exercise_induced_angina

# %% [markdown]
# ### Tree Visualization
# Use the tree_array and the graphviz algorithm to build a tree visualization.

# %%
# Imports for the visualization
import uuid
import sys
# !{sys.executable} -m pip install graphviz
from graphviz import Digraph

# Initialize the graph
dot = Digraph(comment='Heart Data Decision Tree')

'''
# Assign unique ids for all of the tree nodes
id_dict = OrderedDict()
for leaf in tree_array:
    unique_id = str(uuid.uuid4())
    leaf.id = unique_id
    id_dict[unique_id] = leaf
    print unique_id, " = ", leaf.splitting_feature
    
# Assign unique ids for all of the children tree nodes
for leaf in tree_array:
    for child in leaf.children:
        # Check if the id has already been assigned for this child in the id_dict
        for assigned_leaf_id, assigned_leaf in id_dict.iteritems():
            if child.is_equal(assigned_leaf):# The id has already been assigned
                child.id = assigned_leaf_id
'''

# Go through the tree nodes with unique ids and add them as nodes to the graph
for leaf in already_assigned_ids.keys():
    dot.node(str(leaf), already_assigned_ids[leaf].splitting_feature + " = " + ', '.join(str(e) for e in already_assigned_ids[leaf].feature_value))
    
# Go through the children for each and assign edges

print "Length of already assigned ids: ", len(already_assigned_ids.keys())
for leaf in already_assigned_ids.keys():
    print "Processing leaf: ", already_assigned_ids[leaf].splitting_feature
    for child in already_assigned_ids[leaf].children:
        child_id = child.id
        dot.edge(leaf, child_id, constraint='false')
        print "Adding an edge between: ", already_assigned_ids[leaf].splitting_feature, " and ", child.splitting_feature
        print "where the ids are: ", leaf, " and ", child_id
        print "****"
        '''
        for child_leaf in id_dict.keys():
            is_equal_val = id_dict[child_leaf].is_equal(child)
            if is_equal_val:
                print "Adding an edge between :", id_dict[leaf].splitting_feature, " and ", id_dict[child_leaf].splitting_feature
                dot.edge(leaf, child_leaf, constraint='false')
        '''
            
            
        #print "child_id", child_id
        #print [leaf, child_id]
        #dot.edge(leaf, child_id, constraint='false')
        '''
        for key, value in id_dict.iteritems():
            print "Child = ", child.splitting_feature
            print "Value = ", value
            if value == child:
                print "Connecting: ", id_leaf[leaf].splitting_feature, " with ", key
                dot.edges([leaf, key])
        '''

dot.render('heart-decision-tree.gv', view=True)
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python2.7/site-packages
# Length of already assigned ids:  84
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  age
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  serum_cholesterol
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  chest_pain_type
# Adding an edge between:  chest_pain_type  and  oldpeak
# where the ids are:  8d73560b-0288-479e-863f-fb7fac32c374  and  5d878a23-85df-498d-943d-42ff455cf752
# ****
# Adding an edge between:  chest_pain_type  and  oldpeak
# where the ids are:  8d73560b-0288-479e-863f-fb7fac32c374  and  e2e90e78-d567-4b3c-a16c-552ace6ec853
# ****
# Processing leaf:  chest_pain_type
# Adding an edge between:  chest_pain_type  and  maximum_heart_rate_achieved
# where the ids are:  da692019-c216-48ec-9841-9e67d9cf87c1  and  c81977a8-f34c-4275-92d9-9fc7b358447a
# ****
# Adding an edge between:  chest_pain_type  and  maximum_heart_rate_achieved
# where the ids are:  da692019-c216-48ec-9841-9e67d9cf87c1  and  94cd65ed-53c1-41da-aed0-1e9327a75a8a
# ****
# Processing leaf:  serum_cholesterol
# Processing leaf:  chest_pain_type
# Adding an edge between:  chest_pain_type  and  oldpeak
# where the ids are:  52e0d935-6b95-4fcb-a62a-175d5d53ffe6  and  080da109-b853-4555-a59e-0db10821cb04
# ****
# Adding an edge between:  chest_pain_type  and  oldpeak
# where the ids are:  52e0d935-6b95-4fcb-a62a-175d5d53ffe6  and  949ea4f9-9550-44db-be9f-5ced96ad77bd
# ****
# Processing leaf:  oldpeak
# Adding an edge between:  oldpeak  and  exercise_induced_angina
# where the ids are:  6fec8495-09be-46e8-8265-d79a0b081ef2  and  1ef42230-2ce9-4fd2-904a-2c18e2b5cbe7
# ****
# Adding an edge between:  oldpeak  and  exercise_induced_angina
# where the ids are:  6fec8495-09be-46e8-8265-d79a0b081ef2  and  8e70a643-b9c8-4a1d-b4aa-7f5f8dafef38
# ****
# Processing leaf:  maximum_heart_rate_achieved
# Adding an edge between:  maximum_heart_rate_achieved  and  sex
# where the ids are:  46087821-cbf8-43fa-93e8-00c78dfd4c71  and  77d4fa3e-0c72-4b50-8a2e-2b303dcd2039
# ****
# Adding an edge between:  maximum_heart_rate_achieved  and  sex
# where the ids are:  46087821-cbf8-43fa-93e8-00c78dfd4c71  and  6e530ae0-0d91-4756-ab04-c29adbd7fa4e
# ****
# Processing leaf:  exercise_induced_angina
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  chest_pain_type
# Processing leaf:  thal
# Adding an edge between:  thal  and  number_of_major_vessels
# where the ids are:  19c7bf0c-d992-4bc6-b935-a0bc0514e307  and  424661df-b386-4c41-ac73-a65dcd2cc6d2
# ****
# Adding an edge between:  thal  and  number_of_major_vessels
# where the ids are:  19c7bf0c-d992-4bc6-b935-a0bc0514e307  and  85c126b4-73ff-48c3-8580-852af8a47fa7
# ****
# Processing leaf:  thal
# Adding an edge between:  thal  and  chest_pain_type
# where the ids are:  08cc6084-b87d-4519-b118-198c33564a4c  and  cd92d28b-e453-401e-8e4a-655705480b7c
# ****
# Adding an edge between:  thal  and  chest_pain_type
# where the ids are:  08cc6084-b87d-4519-b118-198c33564a4c  and  0c7836e0-7abd-4878-96c9-5f46a6f923e1
# ****
# Adding an edge between:  thal  and  chest_pain_type
# where the ids are:  08cc6084-b87d-4519-b118-198c33564a4c  and  7671d588-a5e0-49a3-9ed8-ead30548cf7f
# ****
# Adding an edge between:  thal  and  chest_pain_type
# where the ids are:  08cc6084-b87d-4519-b118-198c33564a4c  and  9b88e905-688b-439a-a1ff-5b936b8428db
# ****
# Processing leaf:  oldpeak
# Processing leaf:  number_of_major_vessels
# Processing leaf:  number_of_major_vessels
# Processing leaf:  thal
# Processing leaf:  oldpeak
# Processing leaf:  maximum_heart_rate_achieved
# Adding an edge between:  maximum_heart_rate_achieved  and  exercise_induced_angina
# where the ids are:  eb4b70e2-3704-45c5-92e1-c58a24626297  and  16a94a0f-ca71-4400-aa50-f686dcada937
# ****
# Adding an edge between:  maximum_heart_rate_achieved  and  exercise_induced_angina
# where the ids are:  eb4b70e2-3704-45c5-92e1-c58a24626297  and  f2863030-b0ea-4d77-9be9-e6316f47e5d0
# ****
# Processing leaf:  oldpeak
# Processing leaf:  chest_pain_type
# Processing leaf:  thal
# Adding an edge between:  thal  and  chest_pain_type
# where the ids are:  12f9a94f-91c9-4e42-a837-54a9abc5d311  and  18eae70f-f1ea-4855-9681-01cb8b17fa16
# ****
# Adding an edge between:  thal  and  chest_pain_type
# where the ids are:  12f9a94f-91c9-4e42-a837-54a9abc5d311  and  ce99f9d9-2766-4e24-b2c8-075af17bdd50
# ****
# Adding an edge between:  thal  and  chest_pain_type
# where the ids are:  12f9a94f-91c9-4e42-a837-54a9abc5d311  and  3d8db481-1f46-42bb-bb0f-a211f67a6b69
# ****
# Adding an edge between:  thal  and  chest_pain_type
# where the ids are:  12f9a94f-91c9-4e42-a837-54a9abc5d311  and  ced2a5bb-227c-4765-9af4-12f3f05fa3ed
# ****
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  chest_pain_type
# Processing leaf:  oldpeak
# Adding an edge between:  oldpeak  and  slope_peak_exercise
# where the ids are:  23669fbc-eba5-4185-a9ed-7842838c96fc  and  2c451ced-3bfa-4891-bcd8-004da23af22d
# ****
# Adding an edge between:  oldpeak  and  slope_peak_exercise
# where the ids are:  23669fbc-eba5-4185-a9ed-7842838c96fc  and  f5e056b9-037d-454f-bf54-e7f40b19bb90
# ****
# Adding an edge between:  oldpeak  and  slope_peak_exercise
# where the ids are:  23669fbc-eba5-4185-a9ed-7842838c96fc  and  98c93356-797f-4111-a16b-9e95ce07a121
# ****
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  chest_pain_type
# Adding an edge between:  chest_pain_type  and  serum_cholesterol
# where the ids are:  3993c83b-4aa5-454a-8940-4bf6f35320b1  and  8e534764-fb8c-4c70-90b6-2227e2288b1c
# ****
# Adding an edge between:  chest_pain_type  and  serum_cholesterol
# where the ids are:  3993c83b-4aa5-454a-8940-4bf6f35320b1  and  c3d32a0c-f614-4f7e-8bce-6d330fc49a6e
# ****
# Processing leaf:  serum_cholesterol
# Adding an edge between:  serum_cholesterol  and  oldpeak
# where the ids are:  601b98cb-0087-4fa4-8ebf-40b0f29bf028  and  6240df0e-75b3-476a-aad8-e9963b5e5f9f
# ****
# Adding an edge between:  serum_cholesterol  and  oldpeak
# where the ids are:  601b98cb-0087-4fa4-8ebf-40b0f29bf028  and  50648236-0466-4d84-8ca8-efc23f602416
# ****
# Processing leaf:  oldpeak
# Processing leaf:  number_of_major_vessels
# Processing leaf:  oldpeak
# Processing leaf:  chest_pain_type
# Processing leaf:  age
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  exercise_induced_angina
# Processing leaf:  oldpeak
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  oldpeak
# Adding an edge between:  oldpeak  and  number_of_major_vessels
# where the ids are:  1472033b-7198-47e6-9f7e-ed2a027ce4d0  and  07fad1d2-081e-448f-90c6-c6d6a5b9d7af
# ****
# Adding an edge between:  oldpeak  and  number_of_major_vessels
# where the ids are:  1472033b-7198-47e6-9f7e-ed2a027ce4d0  and  e50387c7-d5db-4745-9de8-a19bb7a727ab
# ****
# Processing leaf:  oldpeak
# Processing leaf:  slope_peak_exercise
# Processing leaf:  chest_pain_type
# Adding an edge between:  chest_pain_type  and  oldpeak
# where the ids are:  9da07e88-42c1-40e2-a8b5-2dab2936b3e0  and  9bb2d42a-4603-42cb-9eb3-ac13b5e5c32f
# ****
# Adding an edge between:  chest_pain_type  and  oldpeak
# where the ids are:  9da07e88-42c1-40e2-a8b5-2dab2936b3e0  and  3406c177-ba1d-4ce2-bebc-37ea28e80998
# ****
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  oldpeak
# Processing leaf:  serum_cholesterol
# Processing leaf:  chest_pain_type
# Adding an edge between:  chest_pain_type  and  maximum_heart_rate_achieved
# where the ids are:  c5e24039-d173-4bcc-a75c-d22c1e300986  and  33c3badd-5ba6-400c-8775-2e47b72f11b5
# ****
# Adding an edge between:  chest_pain_type  and  maximum_heart_rate_achieved
# where the ids are:  c5e24039-d173-4bcc-a75c-d22c1e300986  and  a0c922f0-3c60-454c-8403-57a155e59a54
# ****
# Processing leaf:  chest_pain_type
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  sex
# Processing leaf:  exercise_induced_angina
# Processing leaf:  sex
# Processing leaf:  oldpeak
# Processing leaf:  number_of_major_vessels
# Processing leaf:  chest_pain_type
# Processing leaf:  chest_pain_type
# Adding an edge between:  chest_pain_type  and  number_of_major_vessels
# where the ids are:  4b1607a2-9679-4aa1-8e89-477c5b54bde0  and  c30fa6b2-7edd-482c-bf5e-dd5333369d9f
# ****
# Adding an edge between:  chest_pain_type  and  number_of_major_vessels
# where the ids are:  4b1607a2-9679-4aa1-8e89-477c5b54bde0  and  644dcbf0-0189-4afa-8386-611b426b1c8b
# ****
# Processing leaf:  sex
# Processing leaf:  sex
# Processing leaf:  oldpeak
# Processing leaf:  number_of_major_vessels
# Processing leaf:  chest_pain_type
# Processing leaf:  chest_pain_type
# Adding an edge between:  chest_pain_type  and  oldpeak
# where the ids are:  b7b2fcc6-02bd-4b6b-aa1d-25adeb824511  and  c30a2a97-cf26-4473-a01d-01c8e51b01a6
# ****
# Adding an edge between:  chest_pain_type  and  oldpeak
# where the ids are:  b7b2fcc6-02bd-4b6b-aa1d-25adeb824511  and  d358dc1b-8928-4cf1-b187-259088c0e682
# ****
# Processing leaf:  exercise_induced_angina
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  number_of_major_vessels
# Adding an edge between:  number_of_major_vessels  and  maximum_heart_rate_achieved
# where the ids are:  941e6a89-f960-41fe-bc7d-79fe68e31bfa  and  5f9cb1f5-23f7-474c-a6ae-1ecde6bae1e5
# ****
# Adding an edge between:  number_of_major_vessels  and  maximum_heart_rate_achieved
# where the ids are:  941e6a89-f960-41fe-bc7d-79fe68e31bfa  and  36f187cb-5644-4878-a599-525f4e0a10c0
# ****
# Processing leaf:  number_of_major_vessels
# Adding an edge between:  number_of_major_vessels  and  maximum_heart_rate_achieved
# where the ids are:  beec89c2-fa99-4ebb-9d9b-2599a9df7ec4  and  daf061e2-1743-4511-9288-160447e13169
# ****
# Adding an edge between:  number_of_major_vessels  and  maximum_heart_rate_achieved
# where the ids are:  beec89c2-fa99-4ebb-9d9b-2599a9df7ec4  and  100801c9-d26c-4362-bcec-d0181cd4d83c
# ****
# Processing leaf:  age
# Processing leaf:  oldpeak
# Processing leaf:  oldpeak
# Processing leaf:  oldpeak
# Processing leaf:  slope_peak_exercise
# Processing leaf:  number_of_major_vessels
# Processing leaf:  number_of_major_vessels
# Adding an edge between:  number_of_major_vessels  and  sex
# where the ids are:  7e3ff78e-c8d7-4743-a446-e828ab7a0a36  and  addbcc81-129b-45e8-88a5-c0b808027fb2
# ****
# Adding an edge between:  number_of_major_vessels  and  sex
# where the ids are:  7e3ff78e-c8d7-4743-a446-e828ab7a0a36  and  7654b99a-75d4-4423-9435-d8137a018184
# ****
# Processing leaf:  exercise_induced_angina
# Processing leaf:  oldpeak
# Processing leaf:  number_of_major_vessels
# Adding an edge between:  number_of_major_vessels  and  age
# where the ids are:  cffca464-3367-42ac-a0a5-6de03e94f780  and  bd9835ee-9d24-4f7d-982b-bc6e7132cb45
# ****
# Adding an edge between:  number_of_major_vessels  and  age
# where the ids are:  cffca464-3367-42ac-a0a5-6de03e94f780  and  de3193c5-09ad-4c6b-b440-644aa48404cd
# ****
# Processing leaf:  chest_pain_type
# Processing leaf:  age
# Processing leaf:  oldpeak
# Adding an edge between:  oldpeak  and  age
# where the ids are:  f7792fd7-9af0-4475-8d86-78b3ef35c355  and  0f7bd915-5252-4887-9027-c79e48f27bc1
# ****
# Adding an edge between:  oldpeak  and  age
# where the ids are:  f7792fd7-9af0-4475-8d86-78b3ef35c355  and  c8794dfe-7e32-47f9-a1e2-ec92a8269f45
# ****
# Processing leaf:  exercise_induced_angina
# Processing leaf:  maximum_heart_rate_achieved
# Processing leaf:  slope_peak_exercise
# 'heart-decision-tree.gv.pdf'

# %%
for node in tree_array:
    print node.splitting_feature
# Out:
# thal
# thal
# thal
# chest_pain_type
# chest_pain_type
# chest_pain_type
# chest_pain_type
# number_of_major_vessels
# number_of_major_vessels
# chest_pain_type
# chest_pain_type
# chest_pain_type
# chest_pain_type
# serum_cholesterol
# serum_cholesterol
# oldpeak
# oldpeak
# maximum_heart_rate_achieved
# maximum_heart_rate_achieved
# number_of_major_vessels
# number_of_major_vessels
# maximum_heart_rate_achieved
# maximum_heart_rate_achieved
# maximum_heart_rate_achieved
# maximum_heart_rate_achieved
# maximum_heart_rate_achieved
# maximum_heart_rate_achieved
# oldpeak
# oldpeak
# oldpeak
# oldpeak
# oldpeak
# oldpeak
